# %%
#1

import pandas as pd
import numpy as np

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Extract Quantity column as numpy array
quantity_array = df["Quantity"].to_numpy()

# Calculate mean and median
mean_quantity = np.mean(quantity_array)
median_quantity = np.median(quantity_array)

mean_quantity, median_quantity
# Out:
# (np.float64(2.8), np.float64(3.0))

# %%
#2

df_new = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Extract Price column as numpy array
price_array = df_new["Price"].to_numpy()

# Calculate max and min
max_price = np.max(price_array)
min_price = np.min(price_array)

max_price, min_price
# Out:
# (np.int64(55000), np.int64(1500))

# %%
#3

import pandas as pd
import numpy as np

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Convert columns to NumPy arrays
quantity_array = df['Quantity'].to_numpy()
price_array = df['Price'].to_numpy()

# Calculate total revenue per order
revenue_array = quantity_array * price_array

# Print first 10 values using slice operator
print("First 10 revenue values:", revenue_array[:10])
# Out:
# First 10 revenue values: [36000  3000 40000 40000 80000 80000 48000 80000  6000 36000]

# %%
#4

import pandas as pd
import numpy as np

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Convert Quantity column to NumPy array
quantity_array = df['Quantity'].to_numpy()

# Apply min-max normalization
min_val = np.min(quantity_array)
max_val = np.max(quantity_array)
normalized_quantity = (quantity_array - min_val) / (max_val - min_val)

print("Normalized Quantity values:", normalized_quantity)
# Out:
# Normalized Quantity values: [0.66666667 0.33333333 0.33333333 0.         1.         0.33333333
#  1.         0.33333333 1.         0.66666667 1.         0.66666667
#  0.66666667 1.         0.66666667 0.         0.66666667 0.33333333
#  1.         0.         1.         0.33333333 0.33333333 0.33333333
#  0.66666667 0.66666667 1.         1.         0.         0.
#  1.         0.66666667 0.33333333 1.         0.         0.66666667
#  1.         1.         0.66666667 1.         0.66666667 0.33333333
#  0.66666667 0.66666667 0.66666667 1.         1.         0.66666667
#  1.         0.         0.         1.         1.         0.66666667
#  0.33333333 1.         0.         0.66666667 1.         0.
#  0.         0.33333333 0.66666667 0.66666667 0.33333333 0.33333333
#  0.66666667 0.66666667 1.         1.         0.33333333 1.
#  0.         1.         1.         0.         0.33333333 0.
#  1.         0.33333333 1.         0.         0.         1.
# ...

# %%
#5

import pandas as pd

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Display the first 5 rows
print(df.head())
# Out:
#    OrderID CustomerID    Product  Quantity  Price   OrderDate Region  \
# 0      101       C007     Tablet         3  12000  01-04-2024   East
# 1      102       C020  Headphone         2   1500  02-04-2024   East
# 2      103       C015     Camera         2  20000  03-04-2024  South
# 3      104       C011     Tablet         1  40000  04-04-2024  South
# 4      105       C008     Tablet         4  20000  05-04-2024  South
#
#    PaymentMode  TotalAmount
# 0   Debit Card        36000
# 1  Credit Card         3000
# 2   Debit Card        40000
# 3          UPI        40000
# 4          UPI        80000

# %%
#6

import pandas as pd

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")
# Show all unique products ordered
unique_products = df['Product'].unique()

print("Unique products ordered:", unique_products)
# Out:
# Unique products ordered: ['Tablet' 'Headphone' 'Camera' 'Laptop' 'Smartwatch' 'Mobile']

# %%
#7

# Reload the most recent uploaded dataset
df_customer = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Group by CustomerID again (in case user wants direct output here)
orders_per_customer = df_customer.groupby("CustomerID")["OrderID"].count()

orders_per_customer
# Out:
# CustomerID
# C001    5
# C002    6
# C003    5
# C004    6
# C005    3
# C006    2
# C007    8
# C008    9
# C009    6
# C010    4
# C011    4
# C012    8
# C013    3
# C014    4
# C015    8
# C016    4
# C017    3
# C018    5
# C019    4
# C020    3
# Name: OrderID, dtype: int64

# %%
#8

# Reload the latest dataset
df_region = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Calculate average order value (AOV) by Region
avg_order_value_region = df_region.groupby("Region")["TotalAmount"].mean()

avg_order_value_region
# Out:
# Region
# East     64541.666667
# North    74675.000000
# South    65103.448276
# West     60888.888889
# Name: TotalAmount, dtype: float64

# %%
#9

import pandas as pd

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

#Convert the 'OrderDate' column to datetime format with dayfirst=True
df['OrderDate' ] = pd.to_datetime(df['OrderDate'], dayfirst=True)

#Defining the date range
start_date = pd.to_datetime('2024-04-02')
end_date = pd.to_datetime('2024-04-05')

#Filtering the DataFrame for orders within the date range
filtered_orders = df[(df['OrderDate' ] >= start_date) & (df['OrderDate' ] <= end_date)]

#Display the filtered orders
print(filtered_orders)
# Out:
#    OrderID CustomerID    Product  Quantity  Price  OrderDate Region  \
# 1      102       C020  Headphone         2   1500 2024-04-02   East
# 2      103       C015     Camera         2  20000 2024-04-03  South
# 3      104       C011     Tablet         1  40000 2024-04-04  South
# 4      105       C008     Tablet         4  20000 2024-04-05  South
#
#    PaymentMode  TotalAmount
# 1  Credit Card         3000
# 2   Debit Card        40000
# 3          UPI        40000
# 4          UPI        80000

# %%
#10

import pandas as pd

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Assuming you've already loaded your dataset into a DataFrame called df
df_sorted = df.sort_values(by='TotalAmount', ascending=False)

# Display the top rows to verify
print(df_sorted.head())
# Out:
#     OrderID CustomerID     Product  Quantity  Price   OrderDate Region  \
# 27      128       C003  Smartwatch         4  55000  28-04-2024  North
# 96      197       C002      Camera         4  55000  06-07-2024  South
# 90      191       C007      Laptop         4  55000  30-06-2024   East
# 51      152       C004      Mobile         4  55000  22-05-2024  North
# 98      199       C016      Laptop         4  55000  08-07-2024  South
#
#     PaymentMode  TotalAmount
# 27          UPI       220000
# 96          UPI       220000
# 90         Cash       220000
# 51         Cash       220000
# 98  Credit Card       220000

# %%
#11

df['OrderDate'] = pd.to_datetime(df['OrderDate'], dayfirst=True, errors='coerce')

# Count number of orders placed per day
orders_per_day = df.groupby(df['OrderDate'].dt.date)['OrderID'].count().reset_index()

orders_per_day.columns = ['OrderDate', 'TotalOrders']
orders_per_day
# Out:
#      OrderDate  TotalOrders
# 0   2024-04-01            1
# 1   2024-04-02            1
# 2   2024-04-03            1
# 3   2024-04-04            1
# 4   2024-04-05            1
# ..         ...          ...
# 95  2024-07-05            1
# 96  2024-07-06            1
# 97  2024-07-07            1
# 98  2024-07-08            1
# 99  2024-07-09            1
#
# [100 rows x 2 columns]

# %%
#12

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Check missing values per column
missing_values = df.isnull().sum().reset_index()
missing_values.columns = ['Column', 'MissingValues']
missing_values
# Out:
#         Column  MissingValues
# 0      OrderID              0
# 1   CustomerID              0
# 2      Product              0
# 3     Quantity              0
# 4        Price              0
# 5    OrderDate              0
# 6       Region              0
# 7  PaymentMode              0
# 8  TotalAmount              0

# %%
#13

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Fill missing values in Price column with the average price
avg_price = df['Price'].mean(skipna=True)
df['Price'].fillna(avg_price, inplace=True)

# Verify if missing values in Price column are handled
missing_after_fill = df['Price'].isnull().sum()
avg_price, missing_after_fill
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19168\669092517.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price'].fillna(avg_price, inplace=True)
# (np.float64(22275.0), np.int64(0))

# %%
#14

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Drop rows where Product name is missing
df_cleaned = df.dropna(subset=['Product'])

# Count rows before and after dropping
rows_before = df.shape[0]
rows_after = df_cleaned.shape[0]
rows_dropped = rows_before - rows_after

rows_before, rows_after, rows_dropped
# Out:
# (100, 100, 0)

# %%
#15

import pandas as pd

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Replace missing Quantity values with 1
df['Quantity'] = df['Quantity'].fillna(1)

# Show updated missing values count to confirm
missing_values_after = df.isnull().sum()
missing_values_after
# Out:
# OrderID        0
# CustomerID     0
# Product        0
# Quantity       0
# Price          0
# OrderDate      0
# Region         0
# PaymentMode    0
# TotalAmount    0
# dtype: int64

# %%
#16

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Remove duplicate rows based on OrderID (keep the first occurrence)
df = df.drop_duplicates(subset="OrderID", keep="first")

# Check number of duplicates remaining
duplicate_count = df.duplicated(subset="OrderID").sum()
duplicate_count
# Out:
# np.int64(0)

# %%
#17

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Check for negative values in Quantity or Price columns
negative_values = df[(df['Quantity'] < 0) | (df['Price'] < 0)]

# Remove rows with negative Quantity or Price
df = df[(df['Quantity'] >= 0) & (df['Price'] >= 0)]

# Count remaining negative values to confirm removal
remaining_negatives = df[(df['Quantity'] < 0) | (df['Price'] < 0)].shape[0]

negative_values, remaining_negatives
# Out:
# (Empty DataFrame
#  Columns: [OrderID, CustomerID, Product, Quantity, Price, OrderDate, Region, PaymentMode, TotalAmount]
#  Index: [],
#  0)

# %%
#18

import matplotlib.pyplot as plt

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Convert OrderDate to datetime format
df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')

# Group by date and sum TotalAmount
sales_over_time = df.groupby('OrderDate')['TotalAmount'].sum()

# Plot line chart
plt.figure(figsize=(10, 6))
plt.plot(sales_over_time.index, sales_over_time.values, marker='o', linestyle='-', linewidth=2)
plt.title("Sales Over Time", fontsize=14)
plt.xlabel("Order Date", fontsize=12)
plt.ylabel("Total Sales Amount", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.6)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#19

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Group by Region and sum TotalAmount
sales_by_region = df.groupby('Region')['TotalAmount'].sum().sort_values(ascending=False)

# Plot bar chart
plt.figure(figsize=(8, 6))
sales_by_region.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Total Sales by Region", fontsize=14)
plt.xlabel("Region", fontsize=12)
plt.ylabel("Total Sales Amount", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#20

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Group by Product and sum TotalAmount
product_sales = df.groupby('Product')['TotalAmount'].sum()

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(product_sales, labels=product_sales.index, autopct='%1.1f%%', startangle=140)
plt.title("Product Sales Distribution", fontsize=14)
plt.tight_layout()
plt.show()

# %%
#21

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")

# Convert OrderDate to datetime format
df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')

# Count number of orders per day
orders_per_day = df.groupby('OrderDate')['OrderID'].nunique()

# Plot line chart
plt.figure(figsize=(10, 6))
plt.plot(orders_per_day.index, orders_per_day.values, marker='o', linestyle='-', linewidth=2, color='green')
plt.title("Number of Orders Per Day", fontsize=14)
plt.xlabel("Order Date", fontsize=12)
plt.ylabel("Number of Orders", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.6)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#22

import seaborn as sns

df = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\python\\Foundation of Data Analysis\\ecommerce_orders.csv")


# Create boxplot of TotalAmount by Region
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="Region", y="TotalAmount", palette="Set2")
plt.title("Total Amount Distribution by Region", fontsize=14)
plt.xlabel("Region", fontsize=12)
plt.ylabel("Total Amount", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19168\3746302625.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Region", y="TotalAmount", palette="Set2")
